# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_json('data/snli_1.0_test.jsonl', lines=True)

# %%
data.sample(5)
# Out:
#                                        annotator_labels         captionID  \
# 4251  [entailment, entailment, entailment, entailmen...  6147066205.jpg#0
# 2907  [contradiction, neutral, contradiction, contra...  3861381128.jpg#0
# 2493      [neutral, neutral, neutral, neutral, neutral]  4541666784.jpg#4
# 2731  [contradiction, contradiction, contradiction, ...  4169121436.jpg#4
# 5372  [entailment, entailment, entailment, entailmen...  2902269566.jpg#0
#
#          gold_label               pairID  \
# 4251     entailment  6147066205.jpg#0r1e
# 2907  contradiction  3861381128.jpg#0r1c
# 2493        neutral  4541666784.jpg#4r1n
# 2731  contradiction  4169121436.jpg#4r1c
# 5372     entailment  2902269566.jpg#0r1e
#
#                                               sentence1  \
# 4251  A sitting man is holding a partially carved st...
# 2907  Several members of a community are celebrating...
# 2493       Tourists waiting outside of a home to visit.
# ...
